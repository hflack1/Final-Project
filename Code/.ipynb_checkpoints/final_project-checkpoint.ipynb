# %%
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd
from flask import Flask, render_template, redirect
from flask_pymongo import PyMongo
import pymongo
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
import time 
from IPython import get_ipython
import nbconvert

# %%
#Import CSVs of individual WR statistics for years 2009-2019 (source: airyards.com)

ay_2019 = pd.read_csv("../Resources/2019.csv")
ay_2018 = pd.read_csv("../Resources/2018.csv")
ay_2017 = pd.read_csv("../Resources/2017.csv")
ay_2016 = pd.read_csv("../Resources/2016.csv")
ay_2015 = pd.read_csv("../Resources/2015.csv")
ay_2014 = pd.read_csv("../Resources/2014.csv")
ay_2013 = pd.read_csv("../Resources/2013.csv")
ay_2012 = pd.read_csv("../Resources/2012.csv")
ay_2011 = pd.read_csv("../Resources/2011.csv")
ay_2010 = pd.read_csv("../Resources/2010.csv")
ay_2009 = pd.read_csv("../Resources/2009.csv")


# create list of objects for read results
df_list = [ay_2009, ay_2010, ay_2011, ay_2012, ay_2013, ay_2014, ay_2015, ay_2016, ay_2017, ay_2018, ay_2019]


df_list
# Out:
# [    Unnamed: 0            full_name position team  targets  rec  rec_yards  \
#  0            1     Larry Fitzgerald       WR  ARI      154   97       1092
#  1            2     Brandon Marshall       WR  DEN      154  101       1120
#  2            3       DeSean Jackson       WR  PHI      118   63       1167
#  3            4         Mike Wallace       WR  PIT       72   39        756
#  4            5        Jeremy Maclin       WR  PHI       90   55        762
#  5            6        Pierre Garcon       WR  IND       92   47        765
#  6            7          Kenny Britt       WR  TEN       75   42        701
#  7            8     Michael Crabtree       WR   SF       86   48        625
#  8            9             Ted Ginn       WR  MIA       78   38        454
#  9           10       Danny Amendola       WR  STL       63   43        326
#  10          11       Julian Edelman       WR   NE       54   37        359
#  11          12         Jordy Nelson       WR   GB       31   22        320
#  12          13  Darrius Heyward-Bey       WR  OAK       40    9        124
#  13          14           Eric Weems       WR  ATL        6    6         50
#  14          15         Brandon Tate       WR   NE        2    0          0
#  15          16       Matthew Slater       WR   NE        0    0          0
#
#      air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
#  0        1779  312  13  11.6  0.61    0.39       0.26  0.66  284.2
#  1        1367  515  10   8.9  0.82    0.40       0.31  0.74  276.9
#  2        1599  404   9  13.6  0.73    0.36       0.22  0.59  253.4
#  3        1359  143   6  18.9  0.56    0.27       0.13  0.39  155.4
#  4        1057  241   4  11.7  0.72    0.27       0.20  0.48  154.5
#  5        1299  284   4  14.1  0.59    0.28       0.17  0.46  148.5
#  6         997  180   3  13.3  0.70    0.25       0.16  0.42  130.1
#  7         929  219   2  10.8  0.67    0.36       0.22  0.59  122.5
#  8        1239   43   1  15.9  0.37    0.27       0.14  0.40   94.2
#  9         324  186   1   5.1  1.01    0.10       0.13  0.27   81.4
#  10        179  257   1   3.3  2.01    0.06       0.14  0.26   79.4
#  11        374   89   2  12.1  0.86    0.09       0.07  0.17   66.0
#  12        637   12   1  15.9  0.19    0.22       0.13  0.35   29.3
#  13         28   22   2   4.7  1.79    0.01       0.01  0.02   28.3
#  14         73    0   0  36.5  0.00    0.12       0.03  0.13    1.1
#  15          0    0   0   NaN   NaN    0.00       0.00  0.00    0.6  ,
#      Unnamed: 0            full_name position team  targets  rec  rec_yards  \
#  0            1         Mike Wallace       WR  PIT       99   60       1257
#  1            2     Larry Fitzgerald       WR  ARI      173   90       1137
#  2            3        Jeremy Maclin       WR  PHI      115   70        964
#  3            4     Brandon Marshall       WR  MIA      146   86       1014
#  4            5       DeSean Jackson       WR  PHI       96   47       1056
#  5            6        Pierre Garcon       WR  IND      119   68        816
#  6            7       Danny Amendola       WR  STL      123   85        689
#  7            8          Kenny Britt       WR  TEN       73   42        775
#  8            9     Michael Crabtree       WR   SF      101   55        741
#  9           10           Dez Bryant       WR  DAL       72   45        561
#  10          11         Jordy Nelson       WR   GB       64   45        582
#  11          12       Brandon LaFell       WR  CAR       77   38        468
#  12          13         Brandon Tate       WR   NE       46   24        432
#  13          14       Arrelious Benn       WR   TB       38   25        395
#  14          15     Emmanuel Sanders       WR  PIT       50   28        376
#  15          16  Darrius Heyward-Bey       WR  OAK       65   26        366
#  16          17        Andre Roberts       WR  ARI       49   24        307
#  17          18     Demaryius Thomas       WR  DEN       39   22        283
#  18          19        Harry Douglas       WR  ATL       53   22        294
#  19          20          Golden Tate       WR  SEA       39   21        227
#  20          21             Ted Ginn       WR   SF       35   12        163
#  21          22        Antonio Brown       WR  PIT       20   16        167
#  22          23          Eric Decker       WR  DEN        8    6        106
#  23          24       Julian Edelman       WR   NE       14    7         86
#  24          25           Eric Weems       WR  ATL        6    6         61
#  25          26       Matthew Slater       WR   NE        1    0          0
#
#      air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
#  0        1552  352  10  15.7  0.81    0.33       0.21  0.54  249.6
#  1        2106  210   6  12.2  0.54    0.39       0.31  0.74  239.7
#  2        1452  273  10  12.6  0.66    0.29       0.20  0.51  230.0
#  3        1643  226   3  11.3  0.62    0.38       0.29  0.70  205.7
#  4        1567  346   6  16.3  0.67    0.37       0.20  0.56  205.0
#  5        1430  251   6  12.0  0.57    0.28       0.20  0.50  186.2
#  6         644  363   3   5.2  1.07    0.17       0.21  0.43  180.0
#  7        1195  151   9  16.4  0.65    0.35       0.22  0.58  173.5
#  8         999  292   6   9.9  0.74    0.25       0.20  0.48  165.1
#  9         788  193   6  10.9  0.71    0.26       0.16  0.43  137.1
#  10        667  250   2  10.4  0.87    0.13       0.12  0.27  115.2
#  11        793  128   1  10.3  0.59    0.25       0.18  0.44   96.8
#  12        601  151   3  13.1  0.72    0.15       0.09  0.24   91.4
#  13        460  170   2  12.1  0.86    0.12       0.09  0.21   80.0
#  14        631   71   2  12.6  0.60    0.15       0.12  0.28   77.6
#  15        940  106   1  14.5  0.39    0.25       0.15  0.40   73.4
#  16        428  138   2   8.7  0.72    0.09       0.10  0.22   66.7
#  17        355  139   2   9.1  0.80    0.10       0.10  0.22   62.4
#  18        652  124   1  12.3  0.45    0.15       0.10  0.25   56.9
#  19        393  109   0  10.1  0.58    0.12       0.10  0.24   44.1
#  20        526   38   1  15.0  0.31    0.16       0.09  0.24   35.4
#  21        116  113   0   5.8  1.44    0.05       0.08  0.15   32.7
#  22        120   24   1  15.0  0.88    0.04       0.02  0.06   22.6
#  23         46   99   0   3.3  1.87    0.01       0.03  0.06   17.0
#  24         39   22   0   6.5  1.56    0.01       0.01  0.02   12.1
#  25         51    0   0  51.0  0.00    0.02       0.00  0.02    0.0  ,
#      Unnamed: 0            full_name position team  targets  rec  rec_yards  \
#  0            1         Jordy Nelson       WR   GB       96   68       1263
#  1            2     Larry Fitzgerald       WR  ARI      154   80       1411
#  2            3         Mike Wallace       WR  PIT      114   72       1193
#  3            4     Brandon Marshall       WR  MIA      141   81       1221
#  4            5           A.J. Green       WR  CIN      115   65       1057
#  5            6           Dez Bryant       WR  DAL      103   63        928
#  6            7          Julio Jones       WR  ATL       95   54        959
#  7            8        Pierre Garcon       WR  IND      134   70        947
#  8            9        Antonio Brown       WR  PIT      124   69       1108
#  9           10  Darrius Heyward-Bey       WR  OAK      115   64        975
#  10          11     Michael Crabtree       WR   SF      115   73        880
#  11          12       DeSean Jackson       WR  PHI      104   58        961
#  12          13         Torrey Smith       WR  BAL       95   50        841
#  13          14        Jeremy Maclin       WR  PHI       96   63        859
#  14          15         Doug Baldwin       WR  SEA       85   51        788
#  15          16          Eric Decker       WR  DEN       94   44        612
#  16          17        Andre Roberts       WR  ARI       98   51        586
#  17          18       Brandon LaFell       WR  CAR       56   36        613
#  18          19     Demaryius Thomas       WR  DEN       70   32        551
#  19          20        Harry Douglas       WR  ATL       62   39        498
#  20          21          Golden Tate       WR  SEA       58   35        382
#  21          22       Arrelious Benn       WR   TB       51   30        441
#  22          23        Jeremy Kerley       WR  NYJ       47   29        314
#  23          24         Randall Cobb       WR   GB       30   24        369
#  24          25          Kenny Britt       WR  TEN       26   17        289
#  25          26     Emmanuel Sanders       WR  PIT       43   22        288
#  26          27             Ted Ginn       WR   SF       33   19        220
#  27          28           Eric Weems       WR  ATL       14   11         90
#  28          29       Danny Amendola       WR  STL        6    5         45
#  29          30       Julian Edelman       WR   NE        8    4         34
#  30          31       Matthew Slater       WR   NE        3    1         46
#  31          32         Brandon Tate       WR  CIN        0    0          0
#  32          33        Dwayne Harris       WR  DAL        0    0          0
#  33          34          Kamar Aiken       WR  BUF        0    0          0
#  34          35       Terrelle Pryor       WR  OAK        0    0          0
#
#      air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
#  0        1201  411  15  12.5  1.05    0.24       0.17  0.43  284.3
#  1        2051  516   8  13.3  0.69    0.43       0.28  0.72  269.1
#  2        1444  480   8  12.7  0.83    0.29       0.21  0.52  245.0
#  3        1767  312   6  12.5  0.69    0.39       0.30  0.72  239.1
#  4        1516  278   7  13.2  0.70    0.39       0.24  0.62  218.0
#  5        1214  348   9  11.8  0.76    0.31       0.20  0.51  210.3
#  6        1292  407   8  13.6  0.74    0.29       0.19  0.48  203.5
#  7        1530  357   6  11.4  0.62    0.35       0.25  0.62  203.5
#  8        1525  372   2  12.3  0.73    0.31       0.23  0.56  195.9
#  9        1617  264   4  14.1  0.60    0.32       0.23  0.58  185.5
#  10       1057  365   4   9.2  0.83    0.33       0.27  0.63  185.0
#  11       1568  236   4  15.1  0.61    0.31       0.20  0.52  182.2
#  12       1692  238   7  17.8  0.50    0.36       0.19  0.53  180.0
#  13       1172  262   5  12.2  0.73    0.29       0.22  0.53  179.0
#  14        946  310   4  11.1  0.83    0.21       0.17  0.40  153.6
#  15       1377  177   8  14.6  0.44    0.28       0.22  0.52  153.3
#  16        926  226   2   9.4  0.63    0.19       0.18  0.40  124.3
#  17        746  239   3  13.3  0.82    0.16       0.12  0.29  115.3
#  18       1086  113   4  15.5  0.51    0.31       0.27  0.63  111.6
#  19        643  232   1  10.4  0.77    0.15       0.12  0.28   95.1
#  20        659  158   3  11.4  0.58    0.16       0.12  0.30   92.6
#  21        616  174   3  12.1  0.72    0.16       0.10  0.26   91.4
#  22        489  100   1  10.4  0.64    0.13       0.10  0.24   69.2
#  23        292  180   1   9.7  1.26    0.06       0.06  0.13   68.0
#  24        335  122   3  12.9  0.86    0.38       0.23  0.62   63.9
#  25        585  128   2  13.6  0.49    0.17       0.11  0.29   62.8
#  26        369   43   0  11.2  0.60    0.12       0.08  0.21   47.8
#  27         92   30   0   6.6  0.98    0.02       0.02  0.05   20.0
#  28         26   25   0   4.3  1.73    0.14       0.17  0.35    9.5
#  29        106    8   0  13.2  0.32    0.03       0.02  0.04    8.2
#  30        177    0   0  59.0  0.26    0.04       0.01  0.04    5.6
#  31          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  32          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  33          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  34          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0  ,
#      Unnamed: 0            full_name position team  targets  rec  rec_yards  \
#  0            1     Brandon Marshall       WR  CHI      192  118       1508
#  1            2           A.J. Green       WR  CIN      164   97       1350
#  2            3     Demaryius Thomas       WR  DEN      141   94       1442
#  3            4           Dez Bryant       WR  DAL      135   89       1357
#  4            5          Eric Decker       WR  DEN      122   85       1064
#  5            6          Julio Jones       WR  ATL      128   79       1198
#  6            7     Michael Crabtree       WR   SF      127   85       1105
#  7            8         Randall Cobb       WR   GB      104   80        954
#  8            9        Jeremy Maclin       WR  PHI      122   69        857
#  9           10         Mike Wallace       WR  PIT      119   64        838
#  10          11         Torrey Smith       WR  BAL      110   49        855
#  11          12      Justin Blackmon       WR  JAC      132   64        865
#  12          13          T.Y. Hilton       WR  IND       90   50        861
#  13          14        Antonio Brown       WR  PIT      106   66        787
#  14          15     Larry Fitzgerald       WR  ARI      156   71        798
#  15          16        Andre Roberts       WR  ARI      114   64        759
#  16          17         Jordy Nelson       WR   GB       73   49        745
#  17          18          Josh Gordon       WR  CLE       95   50        805
#  18          19          Golden Tate       WR  SEA       67   45        682
#  19          20        Jeremy Kerley       WR  NYJ       95   56        827
#  20          21       Kendall Wright       WR  TEN      104   64        626
#  21          22       Danny Amendola       WR  STL      101   63        666
#  22          23       Brandon LaFell       WR  CAR       76   44        677
#  23          24        Pierre Garcon       WR  WAS       68   45        644
#  24          25  Darrius Heyward-Bey       WR  OAK       80   41        606
#  25          26          Kenny Britt       WR  TEN       90   45        589
#  26          27       DeSean Jackson       WR  PHI       87   45        700
#  27          28        Michael Floyd       WR  ARI       86   45        562
#  28          29     Emmanuel Sanders       WR  PIT       74   44        626
#  29          30        Harry Douglas       WR  ATL       59   38        396
#  30          31         Doug Baldwin       WR  SEA       50   29        366
#  31          32       Alshon Jeffery       WR  CHI       48   24        367
#  32          33       Julian Edelman       WR   NE       32   21        235
#  33          34      Travis Benjamin       WR  CLE       37   18        298
#  30        618   82   3   12.4  0.59    0.17       0.14  0.33   83.6
#  31        759   65   3   15.8  0.48    0.24       0.16  0.40   78.7
#  32        239  138   3    7.5  0.98    0.08       0.09  0.20   67.0
#  33        534   69   2   14.4  0.56    0.15       0.08  0.22   66.4
#  34        383  109   2   10.6  0.81    0.25       0.18  0.44   66.1
#  35        210   71   4    8.4  0.73    0.13       0.13  0.29   56.9
#  36        358   62   3   18.8  0.66    0.16       0.07  0.22   54.1
#  37        397   34   1   12.4  0.51    0.16       0.12  0.29   48.8
#  38        301  115   1    9.7  0.74    0.06       0.05  0.11   45.2
#  39        313   60   1   12.5  0.67    0.07       0.05  0.12   40.1
#  40        335   32   2   12.4  0.47    0.08       0.05  0.14   38.6
#  41        125   59   0    5.2  1.02    0.05       0.07  0.14   27.8
#  42        241   30   0   12.1  0.63    0.12       0.10  0.23   26.1
#  43        313   21   0  313.0  0.07    0.38       0.01  0.29   14.3
#  44         45   23   0    7.5  1.13    0.02       0.03  0.06   10.1
#  45         21   22   0    3.5  1.24    0.01       0.02  0.04    8.2
#  46         93    1   0   13.3  0.33    0.08       0.06  0.14    6.1
#  47         42    1   0   10.5  0.64    0.01       0.01  0.03    4.7
#  48         24    3   0   12.0  0.46    0.02       0.01  0.03    3.1
#  49         -4    5   0   -2.0 -0.25    0.00       0.01  0.01    2.8
#  50          0    0   0    NaN   NaN    0.00       0.00  0.00    0.0
#  51         13    0   0    inf  0.00    0.00       0.00  0.00    0.0  ,
#      Unnamed: 0         full_name position team  targets  rec  rec_yards  \
#  0            1  Demaryius Thomas       WR  DEN      142   92       1430
#  1            2       Josh Gordon       WR  CLE      159   87       1646
#  2            3        A.J. Green       WR  CIN      178   98       1426
#  3            4  Brandon Marshall       WR  CHI      164  100       1295
#  4            5     Antonio Brown       WR  PIT      165  109       1438
#  ..         ...               ...      ...  ...      ...  ...        ...
#  61          62        Eric Weems       WR  CHI        2    1          8
#  62          63      Brandon Tate       WR  CIN        2    1          6
#  63          64      Josh Bellamy       WR  WAS        0    0          0
#  64          65    Matthew Slater       WR   NE        0    0          0
#  65          66   Russell Shepard       WR   TB        0    0          0
#
#      air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
#  0        1385  707  14   9.8  1.03    0.27       0.21  0.50  319.0
#  1        2133  675   9  13.4  0.77    0.44       0.27  0.71  314.4
#  2        2232  390  11  12.5  0.64    0.45       0.30  0.77  306.6
#  3        2000  279  12  12.2  0.65    0.40       0.28  0.70  301.5
#  4        1785  559   8  10.8  0.81    0.37       0.29  0.69  301.2
#  ..        ...  ...  ..   ...   ...     ...        ...   ...    ...
#  61         22    4   0  11.0  0.36    0.01       0.01  0.02    1.8
#  62         13    0   0   6.5  0.46    0.00       0.00  0.01    1.6
#  63          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  64          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  65          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#
#  [66 rows x 16 columns],
#      Unnamed: 0         full_name position team  targets  rec  rec_yards  \
#  0            1     Antonio Brown       WR  PIT      181  129       1698
#  1            2  Demaryius Thomas       WR  DEN      184  111       1619
#  2            3      Jordy Nelson       WR   GB      151   98       1519
#  3            4        Dez Bryant       WR  DAL      136   88       1320
#  4            5  Emmanuel Sanders       WR  DEN      141  101       1404
#  ..         ...               ...      ...  ...      ...  ...        ...
#  89          90    Chris Matthews       WR  SEA        0    0          0
#  90          91      Isaiah Burse       WR  DEN        1    0          0
#  91          92      Josh Bellamy       WR  CHI        1    0          0
#  92          93    Matthew Slater       WR   NE        0    0          0
#  93          94       Walt Powell       WR  NYJ        0    0          0
#
#      air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
#  0        1831  601  13  10.1  0.93    0.33       0.30  0.67  378.1
#  1        1832  659  11  10.0  0.88    0.36       0.30  0.71  338.9
#  2        1727  496  13  11.4  0.88    0.40       0.28  0.70  327.9
#  3        1621  436  16  11.9  0.81    0.39       0.29  0.70  316.0
#  4        1761  379   9  12.5  0.80    0.35       0.23  0.59  299.8
#  ..        ...  ...  ..   ...   ...     ...        ...   ...    ...
#  89          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  90         20    0   0  20.0  0.00    0.01       0.00  0.01    0.0
#  91         51    0   0  51.0  0.00    0.17       0.03  0.16    0.0
#  92          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  93          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#
#  [94 rows x 16 columns],
#       Unnamed: 0         full_name position team  targets  rec  rec_yards  \
#  0             1     Antonio Brown       WR  PIT      193  136       1834
#  1             2       Julio Jones       WR  ATL      203  136       1871
#  2             3  Brandon Marshall       WR  NYJ      173  109       1502
#  3             4   DeAndre Hopkins       WR  HOU      191  111       1521
#  4             5     Odell Beckham       WR  NYG      158   96       1449
#  ..          ...               ...      ...  ...      ...  ...        ...
#  122         123    Matthew Slater       WR   NE        1    0          0
#  123         124     Neal Sterling       WR  JAC        0    0          0
#  124         125         Quan Bray       WR  IND        0    0          0
#  125         126       Vince Mayle       WR  DAL        1    0          0
#  126         127       Walt Powell       WR  BUF        0    0          0
#
#       air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
#  0         2123  587  10  11.0  0.86    0.36       0.33  0.74  382.2
#  1         2063  641   8  10.2  0.91    0.43       0.33  0.79  371.1
#  2         2096  442  14  12.1  0.72    0.38       0.29  0.69  343.2
#  3         2674  231  11  14.0  0.57    0.45       0.31  0.78  329.1
#  4         1829  589  13  11.6  0.79    0.41       0.27  0.69  319.2
#  ..         ...  ...  ..   ...   ...     ...        ...   ...    ...
#  122         34    0   0  34.0  0.00    0.01       0.00  0.01    0.0
#  123          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  124          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  125         23    0   0  23.0  0.00    0.10       0.03  0.11    0.0
#  126          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#
#  [127 rows x 16 columns],
#       Unnamed: 0       full_name position team  targets  rec  rec_yards  \
#  0             1   Antonio Brown       WR  PIT      154  106       1284
#  1             2    Jordy Nelson       WR   GB      152   97       1257
#  2             3      Mike Evans       WR   TB      171   96       1321
#  3             4   Odell Beckham       WR  NYG      169  101       1367
#  4             5     T.Y. Hilton       WR  IND      155   91       1448
#  ..          ...             ...      ...  ...      ...  ...        ...
#  160         161      Eric Weems       WR  ATL        0    0          0
#  161         162    Isaiah Burse       WR   SD        4    0          0
#  162         163   Kalif Raymond       WR  DEN        2    0          0
#  163         164  Kasen Williams       WR  SEA        1    0          0
#  164         165     Vince Mayle       WR  DAL        0    0          0
#
#       air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
#  0         1584  434  12  10.3  0.81    0.33       0.28  0.65  307.3
#  1         1862  361  14  12.2  0.68    0.35       0.25  0.61  306.7
#  2         2500  179  12  14.6  0.53    0.43       0.30  0.74  300.1
#  3         1849  534  10  10.9  0.74    0.39       0.28  0.70  298.6
#  4         1898  342   6  12.2  0.76    0.39       0.27  0.67  271.8
#  ..         ...  ...  ..   ...   ...     ...        ...   ...    ...
#  160          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  161         64    0   0  16.0  0.00    0.03       0.01  0.04    0.0
#  162         66    0   0  33.0  0.00    0.05       0.01  0.06    0.0
#  163         10    0   0  10.0  0.00    0.03       0.03  0.06    0.0
#  164          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#
#  [165 rows x 16 columns],
#       Unnamed: 0         full_name position team  targets  rec  rec_yards  \
#  0             1   DeAndre Hopkins       WR  HOU      174   96       1378
#  1             2     Antonio Brown       WR  PIT      162  101       1533
#  2             3      Keenan Allen       WR  LAC      159  102       1393
#  3             4     Jarvis Landry       WR  MIA      161  112        987
#  4             5  Larry Fitzgerald       WR  ARI      161  109       1156
#  ..          ...               ...      ...  ...      ...  ...        ...
#  150         151     Dwayne Harris       WR  NYG        0    0          0
#  151         152    Krishawn Hogan       WR  IND        0    0          0
#  152         153    Matthew Slater       WR   NE        0    0          0
#  153         154       Stacy Coley       WR  MIN        1    0          0
#  154         155     Victor Bolden       WR   SF        0    0          0
#
#       air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
#  0         2243  359  13  12.9  0.61    0.45       0.35  0.84  311.8
#  1         2176  481   9  13.4  0.70    0.45       0.30  0.77  308.3
#  2         1479  501   6   9.3  0.94    0.31       0.27  0.63  278.2
#  3         1023  498   9   6.4  0.96    0.21       0.27  0.55  264.0
#  4         1354  408   6   8.4  0.85    0.23       0.27  0.56  260.6
#  ..         ...  ...  ..   ...   ...     ...        ...   ...    ...
#  150          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  151          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  152          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  153          6    0   0   6.0  0.00    0.01       0.01  0.03    0.0
#  154          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#
#  [155 rows x 16 columns],
#       Unnamed: 0        full_name position team  targets  rec  rec_yards  \
#  0             1  DeAndre Hopkins       WR  HOU      163  115       1583
#  1             2    Davante Adams       WR   GB      168  110       1370
#  2             3      Julio Jones       WR  ATL      169  112       1655
#  3             4    Antonio Brown       WR  PIT      167  101       1273
#  4             5     Adam Thielen       WR  MIN      153  111       1370
#  ..          ...              ...      ...  ...      ...  ...        ...
#  162         163   Matthew Slater       WR   NE        0    0          0
#  163         164    Nick Williams       WR  TEN        1    0          0
#  164         165    Pharoh Cooper       WR  ARI        0    0          0
#  165         166    Pharoh Cooper       WR   LA        1    0          0
#  166         167     Trevor Davis       WR   GB        0    0          0
#
#       air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
#  0         1995  384  11  12.2  0.79    0.45       0.32  0.80  338.6
#  1         1904  472  13  11.3  0.72    0.36       0.28  0.68  325.0
#  2         2420  449   7  14.3  0.68    0.45       0.28  0.73  320.7
#  3         1899  461  15  11.4  0.67    0.38       0.26  0.66  318.3
#  4         1453  438   9   9.5  0.94    0.33       0.25  0.61  304.2
#  ..         ...  ...  ..   ...   ...     ...        ...   ...    ...
#  162          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  163         27    0   0  27.0  0.00    0.05       0.01  0.05    0.0
#  164          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  165          6    0   0   6.0  0.00    0.00       0.00  0.01    0.0
#  166          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#
#  [167 rows x 16 columns],
#       Unnamed: 0        full_name position team  targets  rec  rec_yards  \
#  0             1   Michael Thomas       WR   NO      185  149       1725
#  1             2     Chris Godwin       WR   TB      121   86       1333
#  2             3      Julio Jones       WR  ATL      157   99       1394
#  3             4      Cooper Kupp       WR   LA      134   94       1161
#  4             5  DeAndre Hopkins       WR  HOU      150  104       1165
#  ..          ...              ...      ...  ...      ...  ...        ...
#  198         199   Juwann Winfree       WR  DEN        0    0          0
#  199         200     Mack Hollins       WR  MIA        1    0          0
#  200         201   Matthew Slater       WR   NE        0    0          0
#  201         202    Taywan Taylor       WR  CLE        1    0          0
#  202         203     Trevor Davis       WR  MIA        0    0          0
#
#       air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr
#  0         1488  583   9   8.0  1.16    0.40       0.32  0.75  374.6
#  1         1301  577   9  10.8  1.02    0.23       0.22  0.49  274.1
#  2         1913  364   6  12.2  0.73    0.37       0.25  0.63  274.1
#  3         1007  538  10   7.5  1.15    0.21       0.21  0.46  270.5
#  4         1580  387   7  10.5  0.74    0.34       0.30  0.69  264.3
#  ..         ...  ...  ..   ...   ...     ...        ...   ...    ...
#  198          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  199         33    0   0  33.0  0.00    0.03       0.01  0.03    0.0
#  200          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#  201         33    0   0  33.0  0.00    0.05       0.02  0.06    0.0
#  202          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0
#
#  [203 rows x 16 columns]]

# %%
#Add Year column

year = 2009

for df in df_list:
    
    df["Year"] = year
    
    year += 1

df_list[10]
# Out:
#      Unnamed: 0        full_name position team  targets  rec  rec_yards  \
# 0             1   Michael Thomas       WR   NO      185  149       1725
# 1             2     Chris Godwin       WR   TB      121   86       1333
# 2             3      Julio Jones       WR  ATL      157   99       1394
# 3             4      Cooper Kupp       WR   LA      134   94       1161
# 4             5  DeAndre Hopkins       WR  HOU      150  104       1165
# ..          ...              ...      ...  ...      ...  ...        ...
# 198         199   Juwann Winfree       WR  DEN        0    0          0
# 199         200     Mack Hollins       WR  MIA        1    0          0
# 200         201   Matthew Slater       WR   NE        0    0          0
# 201         202    Taywan Taylor       WR  CLE        1    0          0
# 202         203     Trevor Davis       WR  MIA        0    0          0
#
#      air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr  Year
# 0         1488  583   9   8.0  1.16    0.40       0.32  0.75  374.6  2019
# 1         1301  577   9  10.8  1.02    0.23       0.22  0.49  274.1  2019
# 2         1913  364   6  12.2  0.73    0.37       0.25  0.63  274.1  2019
# 3         1007  538  10   7.5  1.15    0.21       0.21  0.46  270.5  2019
# 4         1580  387   7  10.5  0.74    0.34       0.30  0.69  264.3  2019
# ..         ...  ...  ..   ...   ...     ...        ...   ...    ...   ...
# 198          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0  2019
# 199         33    0   0  33.0  0.00    0.03       0.01  0.03    0.0  2019
# 200          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0  2019
# 201         33    0   0  33.0  0.00    0.05       0.02  0.06    0.0  2019
# 202          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0  2019
#
# [203 rows x 17 columns]

# %%
merged_df = pd.concat(df_list)

# %%
merged_df
# Out:
#      Unnamed: 0         full_name position team  targets  rec  rec_yards  \
# 0             1  Larry Fitzgerald       WR  ARI      154   97       1092
# 1             2  Brandon Marshall       WR  DEN      154  101       1120
# 2             3    DeSean Jackson       WR  PHI      118   63       1167
# 3             4      Mike Wallace       WR  PIT       72   39        756
# 4             5     Jeremy Maclin       WR  PHI       90   55        762
# ..          ...               ...      ...  ...      ...  ...        ...
# 198         199    Juwann Winfree       WR  DEN        0    0          0
# 199         200      Mack Hollins       WR  MIA        1    0          0
# 200         201    Matthew Slater       WR   NE        0    0          0
# 201         202     Taywan Taylor       WR  CLE        1    0          0
# 202         203      Trevor Davis       WR  MIA        0    0          0
#
#      air_yards  yac  td  adot  racr  ms_air  tgt_share  wopr    ppr  Year
# 0         1779  312  13  11.6  0.61    0.39       0.26  0.66  284.2  2009
# 1         1367  515  10   8.9  0.82    0.40       0.31  0.74  276.9  2009
# 2         1599  404   9  13.6  0.73    0.36       0.22  0.59  253.4  2009
# 3         1359  143   6  18.9  0.56    0.27       0.13  0.39  155.4  2009
# 4         1057  241   4  11.7  0.72    0.27       0.20  0.48  154.5  2009
# ..         ...  ...  ..   ...   ...     ...        ...   ...    ...   ...
# 198          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0  2019
# 199         33    0   0  33.0  0.00    0.03       0.01  0.03    0.0  2019
# 200          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0  2019
# 201         33    0   0  33.0  0.00    0.05       0.02  0.06    0.0  2019
# 202          0    0   0   NaN   NaN    0.00       0.00  0.00    0.0  2019
#
# [1106 rows x 17 columns]

# %%
# add prior year stats

merged_df = merged_df[['full_name', 'Year', 'targets', 'rec', 'rec_yards', 'air_yards', 'yac', 'td', 'adot', 'racr', 'ms_air',
                     'tgt_share', 'wopr', 'ppr']]

merged_df = merged_df.sort_values(by=['full_name', 'Year'], ascending=False)

merged_df.head(20)
# Out:
#          full_name  Year  targets  rec  rec_yards  air_yards  yac  td  adot  \
# 129      Zay Jones  2019       27   20        147        234   58   0   8.7
# 152      Zay Jones  2019       18    7         69        250   19   0  13.9
# 37       Zay Jones  2018      100   54        621       1256  133   6  12.6
# 78       Zay Jones  2017       74   27        316        994   63   2  13.4
# 53     Zach Pascal  2019       72   41        607        800  235   5  11.1
# 92     Zach Pascal  2018       44   26        272        470   71   2  10.7
# 73    Willie Snead  2019       46   31        339        409  126   5   8.9
# 44    Willie Snead  2018       95   62        649        775  276   1   8.2
# 122   Willie Snead  2017       16    8         92        107   32   0   6.7
# 34    Willie Snead  2016      104   72        895        783  387   4   7.5
# 28    Willie Snead  2015      102   70        990       1032  344   3  10.1
# 51     Will Fuller  2019       71   49        670       1011  219   3  14.2
# 63     Will Fuller  2018       45   32        503        623  166   4  13.8
# 55     Will Fuller  2017       50   28        423        794   99   7  15.9
# 62     Will Fuller  2016       92   47        635       1428  238   2  15.5
# 119    Walt Powell  2016       25   14        142        302   45   0  12.1
# 126    Walt Powell  2015        0    0          0          0    0   0   NaN
# 93     Walt Powell  2014        0    0          0          0    0   0   NaN
# 107  Vyncint Smith  2019       31   17        225        378  105   0  12.2
# 164    Vince Mayle  2016        0    0          0          0    0   0   NaN
#
#      racr  ms_air  tgt_share  wopr    ppr
# 129  0.63    0.11       0.08  0.20   35.0
# 152  0.28    0.18       0.12  0.31   13.9
# 37   0.49    0.25       0.21  0.48  152.1
# 78   0.32    0.27       0.17  0.44   70.6
# 53   0.76    0.19       0.14  0.35  133.3
# 92   0.58    0.11       0.08  0.19   66.2
# 73   0.83    0.11       0.10  0.23   95.1
# 44   0.84    0.17       0.18  0.39  134.2
# 122  0.86    0.07       0.06  0.14   17.2
# 34   1.14    0.18       0.17  0.38  185.5
# 28   0.96    0.22       0.16  0.40  187.0
# 51   0.66    0.29       0.20  0.51  134.0
# 63   0.81    0.29       0.20  0.50  106.3
# 55   0.53    0.24       0.16  0.40  113.2
# 62   0.44    0.32       0.18  0.49  122.2
# 119  0.47    0.15       0.12  0.28   28.2
# 126   NaN    0.00       0.00  0.00    0.0
# 93    NaN    0.00       0.00  0.00    0.0
# 107  0.60    0.11       0.07  0.18   50.7
# 164   NaN    0.00       0.00  0.00    0.0

# %%
merged_df['UAY'] = merged_df['air_yards'] - (merged_df['rec_yards'] - merged_df['yac'])

merged_df['Catch %'] = (merged_df['rec']/merged_df['targets']) * 100

merged_df['Yds/tgt'] = (merged_df['rec_yards']/merged_df['targets'])

merged_df['Yds/rec'] = (merged_df['rec_yards']/merged_df['rec'])

merged_df['AY/rec'] = (merged_df['air_yards']/merged_df['rec'])

merged_df['AY/tgt'] = (merged_df['air_yards']/merged_df['targets'])

merged_df['UAY/tgt'] = (merged_df['UAY']/merged_df['targets'])

merged_df['UAY/rec'] = (merged_df['UAY']/merged_df['rec'])

merged_df['YAC/tgt'] = (merged_df['yac']/merged_df['targets'])

merged_df['YAC/rec'] = (merged_df['yac']/merged_df['rec'])

merged_df.head(50)
# Out:
#            full_name  Year  targets  rec  rec_yards  air_yards  yac  td  adot  \
# 129        Zay Jones  2019       27   20        147        234   58   0   8.7
# 152        Zay Jones  2019       18    7         69        250   19   0  13.9
# 37         Zay Jones  2018      100   54        621       1256  133   6  12.6
# 78         Zay Jones  2017       74   27        316        994   63   2  13.4
# 53       Zach Pascal  2019       72   41        607        800  235   5  11.1
# 92       Zach Pascal  2018       44   26        272        470   71   2  10.7
# 73      Willie Snead  2019       46   31        339        409  126   5   8.9
# 44      Willie Snead  2018       95   62        649        775  276   1   8.2
# 122     Willie Snead  2017       16    8         92        107   32   0   6.7
# 34      Willie Snead  2016      104   72        895        783  387   4   7.5
# 28      Willie Snead  2015      102   70        990       1032  344   3  10.1
# 51       Will Fuller  2019       71   49        670       1011  219   3  14.2
# 63       Will Fuller  2018       45   32        503        623  166   4  13.8
# 55       Will Fuller  2017       50   28        423        794   99   7  15.9
# 62       Will Fuller  2016       92   47        635       1428  238   2  15.5
# 119      Walt Powell  2016       25   14        142        302   45   0  12.1
# 126      Walt Powell  2015        0    0          0          0    0   0   NaN
# 93       Walt Powell  2014        0    0          0          0    0   0   NaN
# 107    Vyncint Smith  2019       31   17        225        378  105   0  12.2
# 164      Vince Mayle  2016        0    0          0          0    0   0   NaN
# 125      Vince Mayle  2015        1    0          0         23    0   0  23.0
# 154    Victor Bolden  2017        0    0          0          0    0   0   NaN
# 168   Ventell Bryant  2019        1    1         15         15    0   1  15.0
# 45   Tyrell Williams  2019       64   42        651        870  190   6  13.6
# 43   Tyrell Williams  2018       63   40        631        789  183   5  12.5
# 41   Tyrell Williams  2017       69   43        728        988  320   4  14.3
# 17   Tyrell Williams  2016      119   69       1059       1382  433   7  11.6
# 103  Tyrell Williams  2015        6    2         90        161   51   1  26.8
# 125  23.000000        inf   0.000000        NaN
# 154        NaN        NaN        NaN        NaN
# 168   0.000000   0.000000   0.000000   0.000000
# 45    6.390625   9.738095   2.968750   4.523810
# 43    5.412698   8.525000   2.904762   4.575000
# 41    8.405797  13.488372   4.637681   7.441860
# 17    6.352941  10.956522   3.638655   6.275362
# 103  20.333333  61.000000   8.500000  25.500000
# 31    6.337079   9.724138   3.089888   4.741379
# 6     8.196970  13.195122   3.939394   6.341463
# 8     4.714286   6.600000   4.295238   6.013333
# 22    4.060241   5.524590   3.228916   4.393443
# 12    5.590909   7.500000   2.800000   3.756098
# 16    2.492537   3.036364   3.388060   4.127273
# 52    7.816901  12.333333   2.647887   4.177778
# 61    4.803030   7.731707   3.272727   5.268293
# 38    7.362319   9.960784   3.608696   4.882353
# 16    3.804054   6.255556   2.858108   4.700000
# 14    4.490741   6.381579   3.944444   5.605263
# 89    2.625000   3.818182   2.843750   4.136364
# 59    3.358025   5.037037   2.481481   3.722222
# 105   3.978723   7.192308   1.297872   2.346154
# 131   1.500000   1.666667   1.700000   1.888889
# 136   5.400000   7.714286   5.500000   7.857143
# 186   0.000000   0.000000  10.000000  10.000000
# 202        NaN        NaN        NaN        NaN
# 166        NaN        NaN        NaN        NaN
# 131   4.714286   6.600000   4.857143   6.800000
# 140   6.714286  15.666667   1.142857   2.666667
# 106   3.525000   5.423077   2.550000   3.923077
#
# [50 rows x 24 columns]

# %%
for col in merged_df.columns: 
    print(col)
# Out:
# full_name
# Year
# targets
# rec
# rec_yards
# air_yards
# yac
# td
# adot
# racr
# ms_air
# tgt_share
# wopr
# ppr
# UAY
# Catch %
# Yds/tgt
# Yds/rec
# AY/rec
# AY/tgt
# UAY/tgt
# UAY/rec
# YAC/tgt
# YAC/rec

# %%
name_list = []

name_list2 = []

# Current Year Lists

yearList = []
tgtList = []
recList = []
recYdsList = []
ayList = []
yacList = []
tdList = []
adotList = []
racrList = []
msAirList = []
tgtShareList = []
woprList = []
pprPointsList = []
uayList = []
catchRateList = []
yptList = []
yprList = []
ayPerRecList = []
ayPerTgtList = []
uayPerTgtList = []
uayPerRecList = []
yacPerTgtList = []
yacPerRecList = []


# Prior Years Lists (py = Prior Year)

py_ayList = []
py_tarList = []
py_recList = []
py_ydsList = []
py_yacList = []
py_tdList = []
py_adotList = []
py_racrList = []


for i, row in merged_df.iterrows():
    
    name = row[0]
    year = row[1]
    tar = row[2]
    rec = row[3]
    yds = row[4]
    AY = row[5]
    yac = row[6]
    td = row[7]
    adot = row[8]
    racr = row[9]
    ms_air = row[10]
    tgt_share = row[11]
    wopr = row[12]
    ppr = row[13]
    UAY = row[14]
    catch_rate = row[15]
    ypt = row[16]
    ypr = row[17]
    ayrec = row[18]
    aytar = row[19]
    uaytar = row[20]
    uayrec = row[21]
    yactgt = row[22]
    yacrec = row[23]
    
    if name not in name_list:
        
        name_list.append(name)
        name_list2.append(name)
        yearList.append(year)
        
        tgtList.append(tar)
        recList.append(rec)
        recYdsList.append(yds)
        ayList.append(AY)
        yacList.append(yac)
        tdList.append(td)
        adotList.append(adot)
        racrList.append(racr)
        msAirList.append(ms_air)
        tgtShareList.append(tgt_share)
        woprList.append(wopr)
        pprPointsList.append(ppr)
        uayList.append(UAY)
        catchRateList.append(catch_rate)
        yptList.append(ypt)
        yprList.append(ypr)
        ayPerRecList.append(ayrec)
        ayPerTgtList.append(aytar)
        uayPerTgtList.append(uaytar)
        uayPerRecList.append(uayrec)
        yacPerTgtList.append(yactgt)
        yacPerRecList.append(yacrec)
        
        
        py_ayList.append('')
        py_tarList.append(np.nan)
        py_recList.append('')
        py_ydsList.append('')
        py_yacList.append('')
        py_tdList.append('')
        py_adotList.append('')
        py_racrList.append('')
        
        
        
    else:
        
       
        name_list.append(name)
        name_list2.append(name)
        yearList.append(year)
        
        tgtList.append(tar)
        recList.append(rec)
        recYdsList.append(yds)
        ayList.append(AY)
        yacList.append(yac)
        tdList.append(td)
        adotList.append(adot)
        racrList.append(racr)
        msAirList.append(ms_air)
        tgtShareList.append(tgt_share)
        woprList.append(wopr)
        pprPointsList.append(ppr)
        uayList.append(UAY)
        catchRateList.append(catch_rate)
        yptList.append(ypt)
        yprList.append(ypr)
        ayPerRecList.append(ayrec)
        ayPerTgtList.append(aytar)
        uayPerTgtList.append(uaytar)
        uayPerRecList.append(uayrec)
        yacPerTgtList.append(yactgt)
        yacPerRecList.append(yacrec)
        
        
        py_ayList.append(AY)
        py_tarList.append(tar)
        py_recList.append(rec)
        py_ydsList.append(yds)
        py_yacList.append(yac)
        py_tdList.append(td)
        py_adotList.append(adot)
        py_racrList.append(racr)


py_ayList.append('')
py_ayList.pop(0)
py_tarList.append('')
py_tarList.pop(0)
py_recList.append('')
py_recList.pop(0)
py_ydsList.append('')
py_ydsList.pop(0)
py_yacList.append('')
py_yacList.pop(0)
py_tdList.append('')
py_tdList.pop(0)
py_adotList.append('')
py_adotList.pop(0)
py_racrList.append('')
py_racrList.pop(0)

print("success")
# Out:
# success

# %%
TestList = [name_list, name_list2, yearList, tgtList, recList, recYdsList, ayList, yacList, tdList, adotList, racrList,
            msAirList, tgtShareList, woprList, pprPointsList, uayList, catchRateList, yptList, yprList, ayPerRecList, 
            ayPerTgtList, uayPerTgtList, uayPerRecList, yacPerTgtList, yacPerRecList, py_ayList, py_tarList, py_recList, 
            py_ydsList, py_yacList, py_tdList, py_adotList, py_racrList]

lengthList = []

for list in TestList:
    lengthList.append(len(list))
    
lengthList
# Out:
# [1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106,
#  1106]

# %%
combinedDict = {"full_name": name_list2, "Year": yearList, "PPR_Points": pprPointsList, "Targets": tgtList, 
          "Rec": recList, "Air_Yards": ayList, "YAC": yacList, "TDs": tdList, "ADOT": adotList, "RACR": racrList, 
          "MS_Air": msAirList, "Tgt_Share": tgtShareList, "WOPR": woprList, "UAY": uayList, "Catch_Rate": catchRateList,
          "Yds/Tgt": yptList, "Yds/Rec": yprList, "AY/Tgt": ayPerTgtList, "AY/Rec": ayPerRecList, 
          "UAY/tgt": uayPerTgtList, "UAY/Rec": uayPerRecList, "YAC/Tgt": yacPerTgtList, "YAC/Rec": yacPerRecList,
          
          "PY_AY": py_ayList, "PY_Tgt":py_tarList, "PY_Rec": py_recList, "PY_Yds": py_ydsList, "PY_YAC": py_yacList, 
          "PY_TD": py_tdList, "PY_aDOT": py_adotList,"PY_RACR": py_racrList}


combinedDF = pd.DataFrame(combinedDict)

combinedDF.sort_values(by=['full_name', 'Year'], ascending=False)
combinedDF
# Out:
#         full_name  Year  PPR_Points  Targets  Rec  Air_Yards  YAC  TDs  ADOT  \
# 0       Zay Jones  2019        35.0       27   20        234   58    0   8.7
# 1       Zay Jones  2019        13.9       18    7        250   19    0  13.9
# 2       Zay Jones  2018       152.1      100   54       1256  133    6  12.6
# 3       Zay Jones  2017        70.6       74   27        994   63    2  13.4
# 4     Zach Pascal  2019       133.3       72   41        800  235    5  11.1
# ...           ...   ...         ...      ...  ...        ...  ...  ...   ...
# 1101   A.J. Green  2014       209.3      116   69       1511  309    6  13.0
# 1102   A.J. Green  2013       306.6      178   98       2232  390   11  12.5
# 1103   A.J. Green  2012       301.8      164   97       2239  361   11  13.7
# 1104   A.J. Green  2011       218.0      115   65       1516  278    7  13.2
# 1105   A.J. Brown  2019       217.1       84   52       1107  465    8  13.2
#
#       RACR  ...   YAC/Tgt   YAC/Rec  PY_AY  PY_Tgt  PY_Rec  PY_Yds  PY_YAC  \
# 0     0.63  ...  2.148148  2.900000    250      18       7      69      19
# 1     0.28  ...  1.055556  2.714286   1256     100      54     621     133
# 2     0.49  ...  1.330000  2.462963    994      74      27     316      63
# 3     0.32  ...  0.851351  2.333333            NaN
# 4     0.76  ...  3.263889  5.731707    470      44      26     272      71
# ...    ...  ...       ...       ...    ...     ...     ...     ...     ...
# 1101  0.69  ...  2.663793  4.478261   2232     178      98    1426     390
# 1102  0.64  ...  2.191011  3.979592   2239     164      97    1350     361
# 1103  0.60  ...  2.201220  3.721649   1516     115      65    1057     278
# 1104  0.70  ...  2.417391  4.276923            NaN
# 1105  0.95  ...  5.535714  8.942308
#
#       PY_TD  PY_aDOT  PY_RACR
# 0         0     13.9     0.28
# 1         6     12.6     0.49
# 2         2     13.4     0.32
# 3
# 4         2     10.7     0.58
# ...     ...      ...      ...
# 1101     11     12.5     0.64
# 1102     11     13.7      0.6
# 1103      7     13.2      0.7
# 1104
# 1105
#
# [1106 rows x 31 columns]

# %%
# pd.merge(left, right, how='left', on=['key1', 'key2'])

#merged_df2 = pd.merge(merged_df, pyDF, how='left', on=['full_name', 'Year'])
#merged_df2

# %%
cleaned_df = combinedDF

print(cleaned_df.isnull().sum())
print(cleaned_df.dtypes)
# Out:
# full_name       0
# Year            0
# PPR_Points      0
# Targets         0
# Rec             0
# Air_Yards       0
# YAC             0
# TDs             0
# ADOT           35
# RACR           36
# MS_Air          0
# Tgt_Share       0
# WOPR            0
# UAY             0
# Catch_Rate     37
# Yds/Tgt        37
# Yds/Rec        59
# AY/Tgt         35
# AY/Rec         36
# UAY/tgt        35
# UAY/Rec        36
# YAC/Tgt        37
# YAC/Rec        59
# PY_AY           0
# PY_Tgt        301
# PY_Rec          0
# PY_Yds          0
# PY_YAC          0
# PY_TD           0
# PY_aDOT        26
# PY_RACR        27
# dtype: int64
# full_name      object
# Year            int64
# PPR_Points    float64
# Targets         int64
# Rec             int64
# Air_Yards       int64
# YAC             int64
# TDs             int64
# ADOT          float64
# RACR          float64
# MS_Air        float64
# Tgt_Share     float64
# WOPR          float64
# UAY             int64
# Catch_Rate    float64
# Yds/Tgt       float64
# Yds/Rec       float64
# AY/Tgt        float64
# AY/Rec        float64
# UAY/tgt       float64
# UAY/Rec       float64
# YAC/Tgt       float64
# YAC/Rec       float64
# PY_AY          object
# PY_Tgt         object
# PY_Rec         object
# PY_Yds         object
# PY_YAC         object
# PY_TD          object
# PY_aDOT        object
# PY_RACR        object
# dtype: object

# %%
#cleaned_df['PY_Tgt'] = cleaned_df['PY_Tgt'].astype(float)

#print(cleaned_df['PY_Tgt'].dtypes)
cleaned_df['PY_Tgt']
# Out:
# 0        18
# 1       100
# 2        74
# 3       NaN
# 4        44
#        ...
# 1101    178
# 1102    164
# 1103    115
# 1104    NaN
# 1105
# Name: PY_Tgt, Length: 1106, dtype: object

# %%
# cleaned_df = cleaned_df[['Year', 'targets', 'rec', 'Catch %', 'rec_yards', 'Yds/tgt', 'Yds/rec', 'air_yards', 'adot', 
#                          'AY/rec', 'yac', 'YAC/tgt', 'YAC/rec', 'UAY', 'UAY/tgt', 'UAY/rec', 'racr',
#                          'ms_air', 'tgt_share', 'wopr', 'ppr']]

# cleaned_df = cleaned_df.rename(columns={'targets':'Targets', 'rec':'Rec', 'Catch %': 'Catch_Rate',
#                                         'rec_yards':'Rec_Yds', 'air_yards':'Air_Yds',
#                                         'yac':'YAC', 'adot':'aDOT', 'racr':'RACR', 'ms_air':'MS_AY',
#                                         'tgt_share':'Tgt_Share','wopr':'WOPR', 'ppr': 'PPR_Points'})

cleaned_df = cleaned_df.dropna()

#cleaned_df = cleaned_df.drop(cleaned_df[cleaned_df[cleaned_df['PY_Tgt']] < 0].index, inplace = True)

cleaned_df = cleaned_df.round(2)

cleaned_df.drop(cleaned_df.tail(1).index,inplace=True)

cleaned_df
# Out:
#          full_name  Year  PPR_Points  Targets  Rec  Air_Yards  YAC  TDs  ADOT  \
# 0        Zay Jones  2019        35.0       27   20        234   58    0   8.7
# 1        Zay Jones  2019        13.9       18    7        250   19    0  13.9
# 2        Zay Jones  2018       152.1      100   54       1256  133    6  12.6
# 4      Zach Pascal  2019       133.3       72   41        800  235    5  11.1
# 6     Willie Snead  2019        95.1       46   31        409  126    5   8.9
# ...            ...   ...         ...      ...  ...        ...  ...  ...   ...
# 1099    A.J. Green  2016       186.4      100   66       1236  258    4  12.4
# 1100    A.J. Green  2015       275.7      132   86       1687  336   10  12.8
# 1101    A.J. Green  2014       209.3      116   69       1511  309    6  13.0
# 1102    A.J. Green  2013       306.6      178   98       2232  390   11  12.5
# 1103    A.J. Green  2012       301.8      164   97       2239  361   11  13.7
#
#       RACR  ...  YAC/Tgt  YAC/Rec  PY_AY  PY_Tgt  PY_Rec  PY_Yds  PY_YAC  \
# 0     0.63  ...     2.15     2.90    250      18       7      69      19
# 1     0.28  ...     1.06     2.71   1256     100      54     621     133
# 2     0.49  ...     1.33     2.46    994      74      27     316      63
# 4     0.76  ...     3.26     5.73    470      44      26     272      71
# 6     0.83  ...     2.74     4.06    775      95      62     649     276
# ...    ...  ...      ...      ...    ...     ...     ...     ...     ...
# 1099  0.78  ...     2.58     3.91   1687     132      86    1297     336
# 1100  0.77  ...     2.55     3.91   1511     116      69    1041     309
# 1101  0.69  ...     2.66     4.48   2232     178      98    1426     390
# 1102  0.64  ...     2.19     3.98   2239     164      97    1350     361
# 1103  0.60  ...     2.20     3.72   1516     115      65    1057     278
#
#       PY_TD  PY_aDOT  PY_RACR
# 0         0     13.9     0.28
# 1         6     12.6     0.49
# 2         2     13.4     0.32
# 4         2     10.7     0.58
# 6         1      8.2     0.84
# ...     ...      ...      ...
# 1099     10     12.8     0.77
# 1100      6       13     0.69
# 1101     11     12.5     0.64
# 1102     11     13.7      0.6
# 1103      7     13.2      0.7
#
# [756 rows x 31 columns]

# %%
###Clean DF for ML###

cleaned_df = cleaned_df.drop(columns=["full_name"])

cleaned_df
# Out:
#       Year  PPR_Points  Targets  Rec  Air_Yards  YAC  TDs  ADOT  RACR  MS_Air  \
# 0     2019        35.0       27   20        234   58    0   8.7  0.63    0.11
# 1     2019        13.9       18    7        250   19    0  13.9  0.28    0.18
# 2     2018       152.1      100   54       1256  133    6  12.6  0.49    0.25
# 4     2019       133.3       72   41        800  235    5  11.1  0.76    0.19
# 6     2019        95.1       46   31        409  126    5   8.9  0.83    0.11
# ...    ...         ...      ...  ...        ...  ...  ...   ...   ...     ...
# 1099  2016       186.4      100   66       1236  258    4  12.4  0.78    0.41
# 1100  2015       275.7      132   86       1687  336   10  12.8  0.77    0.38
# 1101  2014       209.3      116   69       1511  309    6  13.0  0.69    0.50
# 1102  2013       306.6      178   98       2232  390   11  12.5  0.64    0.45
# 1103  2012       301.8      164   97       2239  361   11  13.7  0.60    0.48
#
#       ...  YAC/Tgt  YAC/Rec  PY_AY  PY_Tgt  PY_Rec  PY_Yds  PY_YAC  PY_TD  \
# 0     ...     2.15     2.90    250      18       7      69      19      0
# 1     ...     1.06     2.71   1256     100      54     621     133      6
# 2     ...     1.33     2.46    994      74      27     316      63      2
# 4     ...     3.26     5.73    470      44      26     272      71      2
# 6     ...     2.74     4.06    775      95      62     649     276      1
# ...   ...      ...      ...    ...     ...     ...     ...     ...    ...
# 1099  ...     2.58     3.91   1687     132      86    1297     336     10
# 1100  ...     2.55     3.91   1511     116      69    1041     309      6
# 1101  ...     2.66     4.48   2232     178      98    1426     390     11
# 1102  ...     2.19     3.98   2239     164      97    1350     361     11
# 1103  ...     2.20     3.72   1516     115      65    1057     278      7
#
#       PY_aDOT  PY_RACR
# 0        13.9     0.28
# 1        12.6     0.49
# 2        13.4     0.32
# 4        10.7     0.58
# 6         8.2     0.84
# ...       ...      ...
# 1099     12.8     0.77
# 1100       13     0.69
# 1101     12.5     0.64
# 1102     13.7      0.6
# 1103     13.2      0.7
#
# [756 rows x 30 columns]

# %%
#Confirm no nulls

cleaned_df.count()
# Out:
# Year          756
# PPR_Points    756
# Targets       756
# Rec           756
# Air_Yards     756
# YAC           756
# TDs           756
# ADOT          756
# RACR          756
# MS_Air        756
# Tgt_Share     756
# WOPR          756
# UAY           756
# Catch_Rate    756
# Yds/Tgt       756
# Yds/Rec       756
# AY/Tgt        756
# AY/Rec        756
# UAY/tgt       756
# UAY/Rec       756
# YAC/Tgt       756
# YAC/Rec       756
# PY_AY         756
# PY_Tgt        756
# PY_Rec        756
# PY_Yds        756
# PY_YAC        756
# PY_TD         756
# PY_aDOT       756
# PY_RACR       756
# dtype: int64

# %%
cleaned_df.to_csv('test.csv', index=False, header=True)

#ValueError: Input contains infinity or a value too large for dtype('float64').

cleaned_df.dtypes
# Out:
# Year            int64
# PPR_Points    float64
# Targets         int64
# Rec             int64
# Air_Yards       int64
# YAC             int64
# TDs             int64
# ADOT          float64
# RACR          float64
# MS_Air        float64
# Tgt_Share     float64
# WOPR          float64
# UAY             int64
# Catch_Rate    float64
# Yds/Tgt       float64
# Yds/Rec       float64
# AY/Tgt        float64
# AY/Rec        float64
# UAY/tgt       float64
# UAY/Rec       float64
# YAC/Tgt       float64
# YAC/Rec       float64
# PY_AY          object
# PY_Tgt         object
# PY_Rec         object
# PY_Yds         object
# PY_YAC         object
# PY_TD          object
# PY_aDOT        object
# PY_RACR        object
# dtype: object

# %%
for col in cleaned_df.columns: 
    print(col)
# Out:
# Year
# PPR_Points
# Targets
# Rec
# Air_Yards
# YAC
# TDs
# ADOT
# RACR
# MS_Air
# Tgt_Share
# WOPR
# UAY
# Catch_Rate
# Yds/Tgt
# Yds/Rec
# AY/Tgt
# AY/Rec
# UAY/tgt
# UAY/Rec
# YAC/Tgt
# YAC/Rec
# PY_AY
# PY_Tgt
# PY_Rec
# PY_Yds
# PY_YAC
# PY_TD
# PY_aDOT
# PY_RACR

# %%
print("Glossary:")
print("-----------------------------------------------------------")
print("-----------------------------------------------------------")
print("Targets (tgt): # of times the ball was thrown to the WR")
print("-----------------------------------------------------------")
print("Rec (Receptions): # of times the receiver caught the ball")
print("-----------------------------------------------------------")
print("Catch %: Rec/Targets")
print("-----------------------------------------------------------")
print("Rec_Yds (Receiving Yards): Total yards gained on all Recs")
print("-----------------------------------------------------------")
print("Air_Yds: Total distance from the line of scrimmage to where the WR is located at the time the WR is targeted")
print("-----------------------------------------------------------")
print("YAC (Yards After Catch): Yards gained after the receiver catches the ball")
print("-----------------------------------------------------------")
print("UAY (Unrealized Air Yards): total AY on tgts that did not result in a rec (Air_Yds - (Rec_Yds-YAC)")
print("-----------------------------------------------------------")
print("aDOT (Average Depth of Target): Average distance from the line of scrimmage to the point at at which the WR is targeted")
print("-----------------------------------------------------------")
print("RACR (receiver air conversion ratio): Measures yards created per AY (Rec_Yds/Air_Yds)")
print("-----------------------------------------------------------")
print("MS_AY (Market Share of Air Yards): % of total team air yards on tgts to the WR")
print("-----------------------------------------------------------")
print("Tgt_Share (Target Share): % of team targets intended for the WR")
print("-----------------------------------------------------------")
print("WOPR: weighted opportunity rating")
print("-----------------------------------------------------------")
print("PPR_Points: fantasy points scored in PPR (Points Per Reception) scoring format. PPR is the standard scoring format for ESPN")
# Out:
# Glossary:
# -----------------------------------------------------------
# -----------------------------------------------------------
# Targets (tgt): # of times the ball was thrown to the WR
# -----------------------------------------------------------
# Rec (Receptions): # of times the receiver caught the ball
# -----------------------------------------------------------
# Catch %: Rec/Targets
# -----------------------------------------------------------
# Rec_Yds (Receiving Yards): Total yards gained on all Recs
# -----------------------------------------------------------
# Air_Yds: Total distance from the line of scrimmage to where the WR is located at the time the WR is targeted
# -----------------------------------------------------------
# YAC (Yards After Catch): Yards gained after the receiver catches the ball
# -----------------------------------------------------------
# UAY (Unrealized Air Yards): total AY on tgts that did not result in a rec (Air_Yds - (Rec_Yds-YAC)
# -----------------------------------------------------------
# aDOT (Average Depth of Target): Average distance from the line of scrimmage to the point at at which the WR is targeted
# -----------------------------------------------------------
# RACR (receiver air conversion ratio): Measures yards created per AY (Rec_Yds/Air_Yds)
# -----------------------------------------------------------
# MS_AY (Market Share of Air Yards): % of total team air yards on tgts to the WR
# -----------------------------------------------------------
# Tgt_Share (Target Share): % of team targets intended for the WR
# -----------------------------------------------------------
# WOPR: weighted opportunity rating
# -----------------------------------------------------------
# PPR_Points: fantasy points scored in PPR (Points Per Reception) scoring format. PPR is the standard scoring format for ESPN

# %%
#X1 = cleaned_df.Targets.values.reshape(-1, 1)
#y = cleaned_df.PPR_Points.values.reshape(-1, 1) 

#print("Shape: ", X1.shape, y.shape)
#X1

# %%
#plt.scatter(X1, y)

# %%
#X2 = cleaned_df.Air_Yds.values.reshape(-1, 1)
#y = cleaned_df.PPR_Points.values.reshape(-1, 1) 

#print("Shape: ", X2.shape, y.shape)
#X2

# %%
#plt.scatter(X2, y)

# %%
#X3 = cleaned_df.MS_AY.values.reshape(-1, 1)
#y = cleaned_df.PPR_Points.values.reshape(-1, 1) 

#print("Shape: ", X3.shape, y.shape)
#X3

#print(len(y))
#y

#ms_ayDF = cleaned_df["MS_AY"]

# %%
#plt.scatter(X3, y)

# %%
# Create the model and fit the model to the data
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn import datasets
model = LinearRegression()
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pd.set_option('display.max_rows', 1000)

cleaned_df['PY_aDOT']

#pandas.set_option('display.max_rows', 10)
# Out:
# 0       13.9
# 1       12.6
# 2       13.4
# 4       10.7
# 6        8.2
# 7        6.7
# 8        7.5
# 9       10.1
# 11      13.8
# 12      15.9
# 13      15.5
# 23      12.5
# 24      14.3
# 25      11.6
# 26      26.8
# 28      14.4
# 29      11.7
# 30         8
# 32      13.6
# 33        13
# 34      10.6
# 35      13.4
# 37      10.1
# 38       6.8
# 39       8.3
# 41       7.3
# 43        18
# 47         9
# 49       7.1
# 51      11.5
# 53      11.8
# 56      22.9
# 57      15.6
# 58      13.8
# 59      11.5
# 60      18.6
# 61      18.7
# 62      14.4
# 64      13.5
# 65        14
# 66      14.8
# 67      15.5
# 68      18.2
# 69      17.8
# 71       6.8
# 73      10.6
# 76      14.4
# 77        15
# 78       inf
# 82      11.7
# 83      13.6
# 84      15.5
# 85      13.5
# 87      16.6
# 88      12.1
# 89      12.3
# 90      16.2
# 91      15.3
# 92      14.5
# 93        -2
# 94      11.2
# 95        15
# 96      15.9
# 99      14.5
# 101     11.5
# 102       11
# 103     10.4
# 104      7.5
# 105     13.6
# 107     17.6
# 108      1.7
# 109      6.9
# 110      7.3
# 111      4.1
# 112      6.9
# 114       30
# 115        5
# 117     13.5
# 119     11.2
# 120     13.1
# 122     11.1
# 123     12.8
# 124     12.2
# 125     12.9
# 126     13.8
# 127     11.7
# 128     12.4
# 130     11.8
# 131     10.8
# 135     10.4
# 136      9.3
# 137      9.3
# 139      8.6
# 140     11.5
# 141      8.5
# 142     10.6
# 148      8.8
# 149      9.8
# 150      8.4
# 151      9.5
# 154      9.6
# 155     14.4
# 156     14.3
# 157     16.7
# 158     13.3
# 160     20.8
# 161      8.5
# 163      3.4
# 164      4.7
# 166        8
# 167      9.7
# 168      8.8
# 169      9.3
# 170     12.8
# 172       17
# 173      8.1
# 174     13.7
# 175       15
# 176     15.9
# 179     11.7
# 182     11.3
# 183     10.2
# 184       11
# 185     10.8
# 186      9.5
# 187     13.2
# 189     22.9
# 191     15.7
# 192       13
# 193     16.9
# 195     13.2
# 196     11.4
# 197       12
# 198      9.2
# 199     12.1
# 202      5.4
# 204      9.9
# 207     10.8
# 208     10.5
# 209     10.3
# 211      6.5
# 213      8.3
# 214      6.4
# 215      6.4
# 216      7.6
# 217      8.9
# 218      8.1
# 219      7.8
# 220      9.7
# 222      6.8
# 223      8.9
# 224     10.4
# 229     10.3
# 230     10.7
# 231      9.9
# 232      9.3
# 233      9.9
# 234     11.4
# 235       12
# 236     14.1
# 238     10.2
# 239     20.3
# 240       13
# 241       13
# 246      4.4
# 248     12.7
# 249       15
# 250     13.7
# 251       28
# 252     10.8
# 256     12.3
# 257     12.7
# 258     10.9
# 259     11.6
# 260     12.2
# 262      6.6
# 264       27
# 266      5.8
# 267      9.5
# 269      9.9
# 270     10.4
# 271     10.6
# 272     11.3
# 277      8.3
# 278      8.4
# 279      8.3
# 280        8
# 281      7.1
# 282     11.4
# 283     10.2
# 284      8.4
# 287     14.6
# 288     11.5
# 290     12.2
# 291     10.9
# 292     13.3
# 293       15
# 294     13.6
# 295     12.7
# 296     15.7
# 297     18.9
# 299     14.7
# 300     12.6
# 302     15.7
# 303       14
# 304     14.6
# 305     14.7
# 306     14.7
# 309      7.8
# 310      9.6
# 311      8.7
# 313     13.9
# 315      9.8
# 316     15.8
# 317     17.7
# 318     13.7
# 319     11.2
# 321     10.5
# 322     10.4
# 323      9.9
# 324      8.9
# 325      9.4
# 326      7.6
# 327      9.2
# 328      9.9
# 329     10.8
# 331       -2
# 333      9.2
# 345       51
# 349     14.6
# 350     15.2
# 351     14.1
# 352     13.6
# 353     10.5
# 354     12.4
# 356       16
# 358     18.1
# 360     13.3
# 361     14.7
# 362     14.8
# 363       11
# 364     18.8
# 365       20
# 368     12.3
# 370     11.7
# 371     12.1
# 372     10.5
# 373      7.5
# 375     12.7
# 376     14.3
# 377     12.8
# 378     12.2
# 381     18.5
# 384      3.7
# 387       33
# 391      9.3
# 392      8.4
# 393      7.7
# 394      8.8
# 395       10
# 396     10.2
# 397     10.4
# 398     13.3
# 399     12.2
# 400     11.6
# 402     12.1
# 403     19.7
# 408        6
# 410     11.4
# 414     16.3
# 415       15
# 416     14.3
# 417     16.7
# 418     12.7
# 419     15.8
# 421     12.9
# 422     14.8
# 424     15.9
# 425     15.6
# 426     13.1
# 427     12.7
# 428     12.9
# 429     16.4
# 430     13.3
# 432      8.5
# 433     11.7
# 435     11.7
# 436      8.7
# 437      7.9
# 438        7
# 441     11.1
# 442     11.8
# 443       14
# 445      5.1
# 448      8.6
# 449      9.3
# 450      7.1
# 451      7.6
# 452      8.3
# 453     10.4
# 456      9.9
# 457       12
# 462     12.6
# 463     12.2
# 466       33
# 468     24.4
# 472        5
# 474     15.6
# 475     11.8
# 476     15.5
# 477     17.3
# 479      7.1
# 480      8.4
# 481      8.6
# 482      9.8
# 484     10.9
# 486     14.3
# 487     14.2
# 488     14.1
# 489     10.2
# 490     12.5
# 491     10.4
# 492     11.9
# 493     13.6
# 495      7.7
# 496      8.8
# 497      7.6
# 498      7.9
# 499      8.2
# 500      7.5
# 501     13.2
# 502      3.3
# 503      3.3
# 505      8.4
# 506     10.3
# 508     12.4
# 509      7.5
# 512     17.9
# 513     13.6
# 514       43
# 515     15.7
# 516     11.6
# 517     13.4
# 518     13.1
# 520     13.8
# 521     18.8
# 523     11.3
# 524     12.3
# 525     16.2
# 526     10.3
# 527       51
# 531     12.2
# 532     11.4
# 533     10.7
# 534     12.3
# 535     12.5
# 536     10.4
# 537     12.1
# 539     10.4
# 541      8.2
# 542      8.9
# 544     11.7
# 547     13.9
# 548       23
# 550     16.1
# 551     15.6
# 552     14.1
# 553     14.9
# 554     14.9
# 558      9.5
# 559     11.7
# 560       12
# 561     12.4
# 562     17.7
# 563     13.3
# 565     10.3
# 566     13.2
# 567     10.8
# 568     12.2
# 569     12.6
# 570     11.7
# 572      8.6
# 573      5.3
# 574      8.7
# 575      9.4
# 576     10.2
# 577     10.4
# 579        8
# 581     18.8
# 582      7.5
# 585      6.8
# 588     11.9
# 589      6.4
# 590      6.5
# 591      7.4
# 592      5.7
# 594     13.6
# 595     15.3
# 596     12.7
# 597     13.6
# 598     10.2
# 599     12.1
# 601      6.4
# 602      7.6
# 603        4
# 604     10.1
# 605     10.7
# 606     14.9
# 607     10.6
# 609     15.6
# 611      9.1
# 612      7.1
# 613      8.1
# 614      6.1
# 616     16.6
# 621      8.2
# 622       10
# 623       -3
# 625     10.1
# 627     10.5
# 629     17.2
# 630     16.9
# 631     22.6
# 634     10.7
# 641       12
# 642      8.3
# 643      8.6
# 644      8.5
# 645     10.4
# 646     12.3
# 650      6.5
# 651      7.9
# 652        6
# 653      8.1
# 654      5.9
# 655      7.9
# 656     10.9
# 657     14.1
# 658     11.4
# 659     10.1
# 661     12.9
# 662      7.7
# 663     13.4
# 671      8.5
# 672       11
# 673     10.5
# 674      6.6
# 675      6.5
# 676      4.7
# 678     11.7
# 679     11.1
# 680     11.3
# 681     11.4
# 682     14.6
# 683       15
# 686      9.7
# 687      9.4
# 688     10.7
# 689     12.3
# 690     13.8
# 691     12.5
# 692     10.8
# 693     12.1
# 694     13.6
# 695     12.6
# 697      9.4
# 699     -1.2
# 702      8.4
# 703      9.8
# 704      7.1
# 705      9.7
# 709      8.9
# 710      9.6
# 711      9.5
# 712     11.6
# 713     12.4
# 714     11.1
# 716      9.6
# 717     10.1
# 718       11
# 719     12.4
# 720     12.6
# 722     12.3
# 723     13.7
# 724     10.3
# 725       10
# 726     12.2
# 730     13.3
# 731     11.9
# 732     11.5
# 733     12.3
# 734     11.8
# 735     10.9
# 737     16.3
# 738     20.5
# 740     13.4
# 741     12.7
# 742     13.2
# 743     12.8
# 745     10.8
# 746     13.6
# 747     34.3
# 748     11.9
# 749      7.5
# 752     10.2
# 754     10.9
# 755      9.8
# 756     10.5
# 757     10.3
# 758     10.5
# 759       10
# 760      9.8
# 761     10.8
# 762     15.5
# 763      9.1
# 765     11.2
# 766     10.4
# 770      8.5
# 771     12.3
# 773     12.7
# 774     12.6
# 775     11.9
# 776     13.8
# 778     18.9
# 779     16.1
# 780     14.9
# 781     14.8
# 782     14.2
# 783     13.1
# 784     14.9
# 785     15.1
# 786     16.3
# 787     13.6
# 790     12.2
# 791     12.9
# 792     11.9
# 793       14
# 794     12.9
# 795     13.6
# 797      3.4
# 798      3.5
# 800      7.6
# 801      3.6
# 802      1.2
# 803      0.4
# 805     17.4
# 807     11.3
# 808      9.8
# 809     11.9
# 810     10.1
# 811     10.3
# 813     21.6
# 814     20.1
# 815     16.6
# 816     10.3
# 817     13.2
# 818     14.1
# 819     14.5
# 820     15.9
# 824     11.4
# 826      7.9
# 827      8.5
# 828      8.6
# 829      6.9
# 830      7.6
# 831        8
# 832        8
# 833      4.3
# 834      5.2
# 835      5.1
# 837     10.1
# 839     12.5
# 840      8.6
# 841       13
# 843      8.5
# 846      9.8
# 848      8.8
# 850     11.9
# 851     10.7
# 853       14
# 855     16.4
# 857     10.3
# 858     11.8
# 860     14.1
# 862      6.2
# 863      6.1
# 864      4.9
# 865        3
# 866      9.6
# 867      7.7
# 869      8.1
# 870      8.6
# 872      7.4
# 873      6.2
# 874      6.3
# 875      4.8
# 876      6.2
# 877      4.5
# 878      5.2
# 880     19.9
# 881     10.5
# 882     12.7
# 883     10.6
# 884     11.2
# 886     12.2
# 887       33
# 890      9.6
# 893     11.9
# 894     13.6
# 895     10.2
# 897     16.2
# 901     12.7
# 902     13.2
# 903     13.8
# 904     12.9
# 905        8
# 906      7.6
# 908     11.9
# 909     13.2
# 911      8.6
# 912     14.4
# 913      9.5
# 914     10.9
# 916      6.3
# 917      9.3
# 918     11.8
# 920      9.2
# 922     11.8
# 923     14.8
# 927     12.8
# 930       10
# 931     10.2
# 934     10.3
# 938     10.7
# 939       10
# 941        5
# 942       18
# 944     11.8
# 945     11.9
# 946     10.9
# 948     16.1
# 949     14.6
# 950       11
# 951     12.4
# 953     19.7
# 954     13.6
# 958     21.5
# 960     19.7
# 961     15.3
# 962      6.5
# 963     12.5
# 966     36.5
# 968     12.5
# 969     12.1
# 970     11.9
# 971     12.2
# 972     12.1
# 59      11.5     0.67
# 60      18.6     0.37
# 61      18.7     0.43
# 62      14.4     0.56
# 64      13.5      0.4
# 65        14     0.76
# 66      14.8     0.56
# 67      15.5     0.53
# 68      18.2     0.43
# 69      17.8      0.5
# 71       6.8        1
# 73      10.6     0.71
# 76      14.4      0.5
# 77        15     0.35
# 78       inf        0
# 82      11.7     0.83
# 83      13.6     0.66
# 84      15.5     0.62
# 85      13.5     0.74
# 87      16.6     0.45
# 88      12.1     0.93
# 89      12.3     0.64
# 90      16.2     0.47
# 91      15.3     0.48
# 92      14.5     0.56
# 93        -2    -0.25
# 94      11.2      0.6
# 95        15     0.31
# 96      15.9     0.37
# 99      14.5     0.57
# 101     11.5     0.66
# 102       11     0.68
# 103     10.4     1.11
# 104      7.5     0.67
# 105     13.6     0.63
# 107     17.6     0.83
# 108      1.7      1.3
# 109      6.9      0.7
# 110      7.3     0.74
# 111      4.1     1.31
# 112      6.9     0.87
# 114       30     0.42
# 115        5     0.87
# 117     13.5     0.94
# 119     11.2     0.64
#
# [79 rows x 30 columns]

# %%
cleaned_df.PPR_Points.astype(str)

testDF = cleaned_df[['PY_AY', 'PY_Tgt', 'PY_Rec', 'PY_Yds', 'PY_YAC', 'PY_TD', 'PY_RACR', 'PPR_Points']]

#'PY_Tgt', 'PY_Rec', 'PY_Yds', 'PY_YAC', 'PY_TD', *'PY_aDOT', 'PY_RACR', 

testDF['PPR_Points'] = testDF['PPR_Points'].astype(str)
testDF
# Out:
# C:\Users\Joseph\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#      PY_AY PY_Tgt PY_Rec PY_Yds PY_YAC PY_TD PY_RACR PPR_Points
# 0      250     18      7     69     19     0    0.28       35.0
# 1     1256    100     54    621    133     6    0.49       13.9
# 2      994     74     27    316     63     2    0.32      152.1
# 4      470     44     26    272     71     2    0.58      133.3
# 6      775     95     62    649    276     1    0.84       95.1
# ...    ...    ...    ...    ...    ...   ...     ...        ...
# 1099  1687    132     86   1297    336    10    0.77      186.4
# 1100  1511    116     69   1041    309     6    0.69      275.7
# 1101  2232    178     98   1426    390    11    0.64      209.3
# 1102  2239    164     97   1350    361    11     0.6      306.6
# 1103  1516    115     65   1057    278     7     0.7      301.8
#
# [756 rows x 8 columns]

# %%
# PY_AY, PY_Tgt, PY_Rec, PY_Yds, PY_YAC, PY_TD, PY_aDOT, PY_RACR

X =  testDF #.reshape(-1, 1)

#np.array(cleaned_df[MS_Air].tolist())'

y = testDF[["PPR_Points"]].astype(str)  #.reshape(-1, 1)



from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

type(X)
print(y.dtypes)
print(X.dtypes)
# Out:
# PPR_Points    object
# dtype: object
# PY_AY         object
# PY_Tgt        object
# PY_Rec        object
# PY_Yds        object
# PY_YAC        object
# PY_TD         object
# PY_RACR       object
# PPR_Points    object
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-9e749edb7b09> in <module>
# ----> 1 testDF[["PY_aDOT"]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['PY_aDOT'], dtype='object')] are in the [columns]"

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data


X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# %%
# Transform the training and testing data using the X_scaler and y_scaler models


X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
# Create a LinearRegression model and fit it to the scaled training data


from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Make predictions using a fitted model
# Plot the difference between the model predicted values and actual y values, versus the model predicted values
# Hint: You can predict values of X training and testing data using the model.predict() method on a fitted model


predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()
